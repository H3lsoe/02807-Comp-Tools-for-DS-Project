# %%
import data.data_utils as du
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
_, cancer_data = du.load_data()
X_train, y_train, X_val, y_val, X_test, y_test = du.train_val_test_split(cancer_data)

# %%
rf = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    class_weight="balanced",
    random_state=42
)

rf.fit(X_train, y_train)  
y_pred = rf.predict(X_val)

print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Breast       0.81      0.81      0.81        37
#        Colon       0.74      0.82      0.78        34
#         Lung       0.78      0.86      0.82        42
#     Prostate       0.90      0.79      0.84        24
#         Skin       0.72      0.57      0.63        23
#
#     accuracy                           0.79       160
#    macro avg       0.79      0.77      0.78       160
# weighted avg       0.79      0.79      0.79       160
